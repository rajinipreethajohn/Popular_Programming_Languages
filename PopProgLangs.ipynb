# %%
#Import relevant packages and libraries
# !pip3 install bar_chart_race

import pandas as pd
import numpy as np
import bar_chart_race as bcr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 4.6 MB/s eta 0:00:00
# ...

# %%
df = pd.read_csv('/content/sample_data/Popularity of Programming Languages from 2004 to 2023.csv')

df.head
# Out:
# <bound method NDFrame.head of                Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal  \
# 0         July 2004  0.34  0.36  10.01  4.68   0.42  0.00           2.80
# 1       August 2004  0.35  0.36   9.74  4.96   0.46  0.00           2.65
# 2    September 2004  0.41  0.41   9.59  5.04   0.51  0.00           2.64
# 3      October 2004  0.40  0.38   9.47  5.29   0.53  0.00           2.76
# 4     November 2004  0.38  0.38   9.48  5.22   0.55  0.00           2.75
# ..              ...   ...   ...    ...   ...    ...   ...            ...
# 222    January 2023  0.46  0.85   6.84  6.93   0.39  0.82           0.00
# 223   February 2023  0.46  0.89   6.84  6.92   0.37  0.82           0.02
# 224      March 2023  0.46  0.93   6.86  6.81   0.37  0.80           0.09
# 225      April 2023  0.46  0.95   6.73  6.82   0.39  0.81           0.13
# 226        May 2023  0.48  1.02   6.55  6.92   0.40  0.78           0.16
#
# ...

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                 Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  \
# Date
# July 2004       0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0
# August 2004     0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0
# September 2004  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0
# October 2004    0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0
# November 2004   0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0
#
#                 Groovy  Haskell  ...  Powershell  Python     R  Ruby  Rust  \
# Date                             ...
# July 2004         0.03     0.22  ...        0.16    2.51  0.39  0.33  0.24
# August 2004       0.07     0.20  ...        0.15    2.62  0.40  0.40  0.19
# September 2004    0.08     0.21  ...        0.08    2.71  0.40  0.41  0.17
# October 2004      0.09     0.20  ...        0.12    2.91  0.42  0.46  0.12
# November 2004     0.07     0.24  ...        0.12    2.83  0.41  0.44  0.17
#
# ...

# %%
bcr.bar_chart_race(
    df=df,
    title="Popular Programming Languages over the years",
    figsize=(8, 5),  # Note the corrected syntax for figsize
    filename="Programming_Languages.mp4",
    n_bars=10,
    period_length=1000,
    steps_per_period=60,
    filter_column_colors=True
)
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
